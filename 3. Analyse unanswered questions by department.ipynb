# %% [markdown]
# # 3. Analyse unanswered questions by department
#
# The third stage of our analysis is to look at unanswered questions.
#
# The big departments with relatively high 'not held' counts are the DHSC, DWP, MoJ, and Home Office - these departments provide "not answered" responses to a high proportion of requests for quantitative information.

# %%
import pandas as pd

# %matplotlib inline
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv('./data/output/questions_with_flags.csv', low_memory=False)
len(df)
# Out:
# 203938

# %% [markdown]
# ## Which department gets the most quantitative questions?
#
# - As an absolute number, DHSC, Home Office, DWP, MoD, MoJ
# - As a proportion of all their WQs, the Attorney General, MoJ, MoD, DWP and the Home Office.
#
# So that suggests that there is a particularly high demand for quantitative and statistical info from those departments.

# %%
df_quantitative = df[df.is_quantitative]

# %%
# pd.concat(
#     [df_quantitative.department.value_counts().head(10),
#      df_quantitative.department.value_counts(normalize=True).head(10)], 
#     axis=1)

# %% [markdown]
# Among departments of any size, the MoJ and Attorney General receive the highest proportion of quantitative questions, followed by the MoD, DWP, Home Office and DfE.

# %%
temp = df.groupby(df.department).agg(total_quant=('is_quantitative', 'sum'), total_questions=('is_quantitative', 'size'))
temp['proportion_quant'] = temp.total_quant / temp.total_questions * 100
temp[temp.total_questions > 100].sort_values("proportion_quant", ascending=False)
# Out:
#                                                          total_quant  \
# department
# Attorney General                                                 251
# Ministry of Justice                                             2545
# Ministry of Defence                                             3081
# Department for Work and Pensions                                3015
# Home Office                                                     4269
# Scotland Office                                                  110
# Cabinet Office                                                  1125
# Department for Education                                        2554
# House of Commons Commission                                       48
# Treasury                                                        2144
# The Senior Deputy Speaker                                         35
# Department of Health and Social Care                            6659
# Northern Ireland Office                                          186
# Leader of the House                                               23
# Ministry of Housing, Communities and Local Government            784
# Wales Office                                                      81
# Department for Business and Trade                                248
# Department for Energy Security and Net Zero                      344
# Department for International Trade                               434
# Department for Business, Energy and Industrial Strategy         2006
# Department for Levelling Up, Housing and Communities             820
# Department for Transport                                        1984
# Department for Culture, Media and Sport                          132
# Department for Science, Innovation and Technology                125
# Department for Environment, Food and Rural Affairs              1355
# Department for International Development                         131
# Church Commissioners                                              30
# Prime Minister                                                    24
# Department for Digital, Culture, Media and Sport                 686
# Foreign, Commonwealth and Development Office                    1582
# Cop26                                                             24
# Foreign and Commonwealth Office                                  182
# Women and Equalities                                              40
#
#                                                          total_questions  \
# department
# Attorney General                                                     679
# Ministry of Justice                                                 7080
# Ministry of Defence                                                10172
# Department for Work and Pensions                                   10708
# Home Office                                                        16181
# Scotland Office                                                      462
# Cabinet Office                                                      4789
# Department for Education                                           13135
# House of Commons Commission                                          256
# Treasury                                                           12138
# The Senior Deputy Speaker                                            201
# Department of Health and Social Care                               39376
# Northern Ireland Office                                             1149
# Leader of the House                                                  144
# Ministry of Housing, Communities and Local Government               5012
# Wales Office                                                         518
# Department for Business and Trade                                   1591
# Department for Energy Security and Net Zero                         2305
# Department for International Trade                                  2913
# Department for Business, Energy and Industrial Strategy            13569
# Department for Levelling Up, Housing and Communities                5625
# Department for Transport                                           13696
# Department for Culture, Media and Sport                              926
# Department for Science, Innovation and Technology                    893
# Department for Environment, Food and Rural Affairs                 11219
# Department for International Development                            1127
# Church Commissioners                                                 264
# Prime Minister                                                       220
# Department for Digital, Culture, Media and Sport                    6324
# Foreign, Commonwealth and Development Office                       17440
# Cop26                                                                285
# Foreign and Commonwealth Office                                     2476
# Women and Equalities                                                 815
#
#                                                          proportion_quant
# department
# Attorney General                                                36.966127
# Ministry of Justice                                             35.946328
# Ministry of Defence                                             30.289029
# Department for Work and Pensions                                28.156518
# Home Office                                                     26.382795
# Scotland Office                                                 23.809524
# Cabinet Office                                                  23.491334
# Department for Education                                        19.444233
# House of Commons Commission                                     18.750000
# Treasury                                                        17.663536
# The Senior Deputy Speaker                                       17.412935
# Department of Health and Social Care                            16.911317
# Northern Ireland Office                                         16.187990
# Leader of the House                                             15.972222
# Ministry of Housing, Communities and Local Government           15.642458
# Wales Office                                                    15.637066
# Department for Business and Trade                               15.587681
# Department for Energy Security and Net Zero                     14.924078
# Department for International Trade                              14.898730
# Department for Business, Energy and Industrial Strategy         14.783698
# Department for Levelling Up, Housing and Communities            14.577778
# Department for Transport                                        14.485981
# Department for Culture, Media and Sport                         14.254860
# Department for Science, Innovation and Technology               13.997760
# Department for Environment, Food and Rural Affairs              12.077725
# Department for International Development                        11.623780
# Church Commissioners                                            11.363636
# Prime Minister                                                  10.909091
# Department for Digital, Culture, Media and Sport                10.847565
# Foreign, Commonwealth and Development Office                     9.071101
# Cop26                                                            8.421053
# Foreign and Commonwealth Office                                  7.350565
# Women and Equalities                                             4.907975

# %% [markdown]
# # Proportion unanswered by department
#
# Examine the proportion of answers that came back saying "we do not hold this data", by department.
#
# Obviously this needs to be approached with caution, because as previously noted this contains both false positives and false negatives.
#
# But it gives us a rough idea!

# %%
df_by_department = df.groupby("department").agg(
    {'contains_not_held_string': 'sum',
     'is_quantitative': 'sum',
     'contains_not_held_string_and_isquant': 'sum',
     'url': 'count'
})
df_by_department.rename(columns={"url": "total_questions"}, inplace=True)
df_by_department.head()
df_by_department["percent_wqs_quantitative"] = (df_by_department.is_quantitative / df_by_department.total_questions * 100)
df_by_department["percent_wqs_notheld"] = df_by_department.contains_not_held_string / df_by_department.is_quantitative * 100
df_by_department["percent_of_quant_wqs_notheld"] = df_by_department.contains_not_held_string_and_isquant / df_by_department.is_quantitative * 100
df_by_department.sort_values(by="percent_of_quant_wqs_notheld", ascending=False, inplace=True)

# %% [markdown]
# The big departments with relatively high 'not held' counts are the DHSC, DWP, MoJ, and Home Office.
#
# The big departments with relatively low 'not held' counts include DfT and the Treasury.

# %%
cols = ["total_questions", "is_quantitative", "percent_of_quant_wqs_notheld"]
df_by_department[df_by_department.total_questions > 100][cols].sort_values("percent_of_quant_wqs_notheld", ascending=False)
# Out:
#                                                     total_questions  \
# department
# Church Commissioners                                            264
# Department of Health and Social Care                          39376
# Home Office                                                   16181
# Attorney General                                                679
# Department for Work and Pensions                              10708
# Ministry of Justice                                            7080
# Leader of the House                                             144
# Department for Education                                      13135
# Ministry of Housing, Communities and Local Gove...             5012
# Treasury                                                      12138
# Department for Levelling Up, Housing and Commun...             5625
# Cabinet Office                                                 4789
